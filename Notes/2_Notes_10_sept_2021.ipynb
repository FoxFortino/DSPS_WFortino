# %% [markdown]
# # 10 Sept 2021
#
# Admin
# - Homework will be do at midnight on Thursdays
# - Markdown file in the HW folder on GitHub will have the reading assignment and directions.
#
# Homework grade
# - Remember we are graded on the plots and the captions, model goodness of fit or whatever. Not the code. <b>Remember axis labels</b> and such.
# - After looking at figures, Xiaolong will run the notebook and it must run perfectly to ensure reproducibility.

# %%
import numpy as np
import scipy as sp
from scipy import stats
import matplotlib.pyplot as plt

# %%
coinflips100 = sp.stats.binom.rvs(100, 0.5, loc=0, size=100000)

plt.figure(figsize=(12, 6))
plt.hist(coinflips100, histtype="step", density=True, bins=100, range=(0, 100))
plt.plot(sp.stats.binom.pmf(np.arange(0, 100), 100, 0.5))
plt.show()
